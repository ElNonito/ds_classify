# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import PIL
# Construct a tf.data.Dataset
import pandas as pd

# %%
ds = tfds.load('colorectal_histology', split='train', shuffle_files=True)

# %%
Load_dataset = pd.read_csv("/home/arno/tensorflow_datasets/colorectal_histology/2.0.0/colorectal_histology-train.tfrecord-00001-of-00002")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_102262/4051409104.py in <module>
# ----> 1 Load_dataset = pd.read_csv("/home/arno/tensorflow_datasets/colorectal_histology/2.0.0/colorectal_histology-train.tfrecord-00001-of-00002")
#
# ...

# %%
Load_dataset
# Out:
#                                                      {
#     "pythonClassName": "tensorflow_datasets.cor... NaN
#     "featuresDict": {                              NaN
#         "features": {                              NaN
#             "filename": {                          NaN
#                 "pythonClassName": "tensorflow_... NaN
#                 "text": {}                         NaN
#             }                                      NaN
#             "label": {                             NaN
#                 "pythonClassName": "tensorflow_... NaN
#                 "classLabel": {                    NaN
#                     "numClasses": "8"              NaN
#                 }                                  NaN
#             }                                      NaN
#             "image": {                             NaN
#                 "pythonClassName": "tensorflow_... NaN
#                 "image": {                         NaN
# ...
